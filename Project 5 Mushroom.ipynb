# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
mr = pd.read_csv("/home/pavankumar/data_sci_dec/datasets/mushroom_csv.csv")
mr
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0            x           s         n          t    p               f
# 1            x           s         y          t    a               f
# 2            b           s         w          t    l               f
# 3            x           y         w          t    p               f
# 4            x           s         g          f    n               f
# ...        ...         ...       ...        ...  ...             ...
# 8119         k           s         n          f    n               a
# 8120         x           s         n          f    n               a
# 8121         f           s         n          f    n               a
# 8122         k           y         n          f    y               f
# 8123         x           s         n          f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# ...

# %%
mr.columns
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises%3F', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat', 'class'],
#       dtype='object')

# %%
mr.values
# Out:
# array([['x', 's', 'n', ..., 's', 'u', 'p'],
#        ['x', 's', 'y', ..., 'n', 'g', 'e'],
#        ['b', 's', 'w', ..., 'n', 'm', 'e'],
#        ...,
#        ['f', 's', 'n', ..., 'c', 'l', 'e'],
#        ['k', 'y', 'n', ..., 'v', 'l', 'p'],
#        ['x', 's', 'n', ..., 'c', 'l', 'e']], dtype=object)

# %%
mr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 8124 non-null   object
#  1   cap-surface               8124 non-null   object
#  2   cap-color                 8124 non-null   object
#  3   bruises%3F                8124 non-null   object
#  4   odor                      8124 non-null   object
#  5   gill-attachment           8124 non-null   object
#  6   gill-spacing              8124 non-null   object
#  7   gill-size                 8124 non-null   object
#  8   gill-color                8124 non-null   object
#  9   stalk-shape               8124 non-null   object
#  10  stalk-root                5644 non-null   object
#  11  stalk-surface-above-ring  8124 non-null   object
#  12  stalk-surface-below-ring  8124 non-null   object
# ...

# %%
mr.shape
# Out:
# (8124, 23)

# %%
mr.isnull().sum()
# Out:
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises%3F                     0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# class                          0
# dtype: int64

# %%
# plt.figure(figsize=(12,12))
sns.heatmap(mr.isnull())

# %%
mr.drop('stalk-root',axis=1,inplace=True)

# %%
# seperating Object datas and working on it
objem=mr.select_dtypes(include=['object'])
objem.columns
# Out:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises%3F', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type',
#        'veil-color', 'ring-number', 'ring-type', 'spore-print-color',
#        'population', 'habitat', 'class'],
#       dtype='object')

# %%
intem=mr.select_dtypes(include=['int64'])
intem.columns
# Out:
# Index([], dtype='object')

# %%
floatem=mr.select_dtypes(include=['float64'])
floatem.columns
# Out:
# Index([], dtype='object')

# %%
classified_lis=[]
for col in objem.columns:
    print('Column Name is:',col)
    print(mr[col].value_counts())
    print("========================")
    classified_lis.append(col)
# Out:
# Column Name is: cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
# ...
# Column Name is: cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
# ...
# Column Name is: cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# r      16
# u      16
# Name: cap-color, dtype: int64
# ...
# Column Name is: bruises%3F
# f    4748
# t    3376
# Name: bruises%3F, dtype: int64
# ...
# Column Name is: odor
# n    3528
# f    2160
# y     576
# s     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
# ...
# Column Name is: gill-attachment
# f    7914
# a     210
# Name: gill-attachment, dtype: int64
# ...
# Column Name is: gill-spacing
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
# ...
# Column Name is: gill-size
# b    5612
# n    2512
# Name: gill-size, dtype: int64
# ...
# Column Name is: gill-color
# b    1728
# p    1492
# ...

# %%
len(classified_lis)
# Out:
# 22

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
le=LabelEncoder()
oe=OneHotEncoder()

# %%
# le.fit_transform(mr)

# %%
# from collections import defaultdict
# encoder_dict = defaultdict(LabelEncoder)
# labeled_df = mr.apply(lambda x: encoder_dict[x.name].fit_transform(x))
# labeled_df

# %%
lis=[]
le=LabelEncoder()
for i in classified_lis:
    mr[i] = le.fit_transform(mr[i])
    lis.append(i)

# %%
lis
# Out:
# ['cap-shape',
#  'cap-surface',
#  'cap-color',
#  'bruises%3F',
#  'odor',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-size',
#  'gill-color',
#  'stalk-shape',
#  'stalk-surface-above-ring',
#  'stalk-surface-below-ring',
#  'stalk-color-above-ring',
#  'stalk-color-below-ring',
#  'veil-type',
#  'veil-color',
#  'ring-number',
#  'ring-type',
#  'spore-print-color',
#  'population',
#  'habitat',
#  'class']

# %%
mr.corr()
# Out:
#                           cap-shape  cap-surface  cap-color  bruises%3F  \
# cap-shape                  1.000000    -0.050454  -0.048203   -0.035374
# cap-surface               -0.050454     1.000000  -0.019402    0.070228
# cap-color                 -0.048203    -0.019402   1.000000   -0.000764
# bruises%3F                -0.035374     0.070228  -0.000764    1.000000
# odor                      -0.021935     0.045233  -0.387121   -0.061825
# gill-attachment            0.078865    -0.034180   0.041436    0.137359
# gill-spacing               0.013196    -0.282306   0.144259   -0.299473
# gill-size                  0.054050     0.208100  -0.169464   -0.369596
# gill-color                -0.006039    -0.161017   0.084659    0.527120
# stalk-shape                0.063794    -0.014123  -0.456496    0.099364
# stalk-surface-above-ring  -0.030417     0.089090  -0.060837    0.460824
# stalk-surface-below-ring  -0.032591     0.107965  -0.047710    0.458983
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(mr.corr(),linecolor="black",annot=True,fmt='.2f')

# %%
mr.drop('veil-type',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(mr.corr(),linecolor="black",annot=True,fmt='.2f')

# %%
mr[['stalk-surface-above-ring',
 'stalk-surface-below-ring']]
# Out:
#       stalk-surface-above-ring  stalk-surface-below-ring
# 0                            2                         2
# 1                            2                         2
# 2                            2                         2
# 3                            2                         2
# 4                            2                         2
# ...                        ...                       ...
# 8119                         2                         2
# 8120                         2                         2
# 8121                         2                         2
# 8122                         2                         1
# 8123                         2                         2
#
# [8124 rows x 2 columns]

# %%
mr.drop('stalk-surface-above-ring',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-e11cfa9ccfb4> in <module>
# ----> 1 mr.drop('stalk-surface-above-ring',axis=1,inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(mr.corr(),linecolor="black",annot=True,fmt='.2f')

# %%
mr[['stalk-color-above-ring',
 'stalk-color-below-ring']]
# Out:
#       stalk-color-above-ring  stalk-color-below-ring
# 0                          7                       7
# 1                          7                       7
# 2                          7                       7
# 3                          7                       7
# 4                          7                       7
# ...                      ...                     ...
# 8119                       5                       5
# 8120                       5                       5
# 8121                       5                       5
# 8122                       7                       7
# 8123                       5                       5
#
# [8124 rows x 2 columns]

# %%
mr.drop('stalk-color-above-ring',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(mr.corr(),linecolor="black",annot=True,fmt='.2f')

# %%
mr.skew()
# Out:
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises%3F                  0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-surface-below-ring   -0.757703
# stalk-color-below-ring     -1.791593
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# class                       0.071946
# dtype: float64

# %%
sns.distplot(mr['population'])

# %%
plt.figure(figsize=(20,5))
mr.boxplot()

# %%
# Dataset is in classified so we cannot remove outliers and skewsness

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(mr.drop('class',axis=1), 
                                                    mr['class'], test_size=0.30, 
                                                    random_state=150)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
logmodel.score(X_train,y_train)
# Out:
# 0.9535701723531481

# %%
predictions = logmodel.predict(X_test)

# %%
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9360131255127153
# [[1183   58]
#  [  98 1099]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94      1241
#            1       0.95      0.92      0.93      1197
#
#     accuracy                           0.94      2438
#    macro avg       0.94      0.94      0.94      2438
# weighted avg       0.94      0.94      0.94      2438

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(mr.drop('class',axis=1), 
                                                    mr['class'], test_size=0.30, 
                                                    random_state=150)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.9360131255127153 and best random state is 30

# %%
X_train, X_test, y_train, y_test = train_test_split(mr.drop('class',axis=1), 
                                                    mr['class'], test_size=0.30, 
                                                    random_state=30)

# %%
mod=GaussianNB()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9142739950779327
# [[1184  120]
#  [  89 1045]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1304
#            1       0.90      0.92      0.91      1134
#
#     accuracy                           0.91      2438
#    macro avg       0.91      0.91      0.91      2438
# weighted avg       0.91      0.91      0.91      2438

# %%
def svc(a='rbf'):
    mod=SVC(kernel=a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
svc('poly')
# Out:
# 0.9987694831829368
# [[1304    0]
#  [   3 1131]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
svc('linear')
# Out:
# 0.9548810500410172
# [[1267   37]
#  [  73 1061]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      1304
#            1       0.97      0.94      0.95      1134
#
#     accuracy                           0.95      2438
#    macro avg       0.96      0.95      0.95      2438
# weighted avg       0.96      0.95      0.95      2438

# %%
svc()
# Out:
# 0.9885151763740772
# [[1296    8]
#  [  20 1114]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1304
#            1       0.99      0.98      0.99      1134
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %%
def tree(a='gini'):    
    mod=DecisionTreeClassifier(a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
tree()
# Out:
# 1.0
# [[1304    0]
#  [   0 1134]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
tree('entropy')
# Out:
# 1.0
# [[1304    0]
#  [   0 1134]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestClassifier(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        predictions = mod.predict(X_test)
        accuaracy=accuracy_score(y_test,predictions)
        if accuaracy>accu:
            accu=accuaracy
            best_n=i
    mod=RandomForestClassifier(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))
    print("best n is ", best_n)
    print()

# %%
rndtree(list(np.arange(100,200)),30)
# Out:
# 1.0
# [[1304    0]
#  [   0 1134]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
#
# best n is  100

# %%
mod=KNeighborsClassifier()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9963084495488105
# [[1300    4]
#  [   5 1129]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
mod=LogisticRegression()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9466776045939295
# [[1262   42]
#  [  88 1046]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      1304
#            1       0.96      0.92      0.94      1134
#
#     accuracy                           0.95      2438
#    macro avg       0.95      0.95      0.95      2438
# weighted avg       0.95      0.95      0.95      2438

# %%
# From Above readings best model is [RandomForestClassifier, DecisionTreeClassifier()] with 100%

# %% [markdown]
# # Hyper Tunning

# %%
parameters={'max_iter':[500,700,900,1100,1300,1500,1700],
           'penalty':['elsticnet','l1','l2']}
from sklearn.model_selection import GridSearchCV

# %%
gcv=GridSearchCV(estimator=RandomForestClassifier(),param_grid={'n_estimators': [100, 200], 'random_state': [30,100]},cv=5)

# %%
gcv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [100, 200], 'random_state': [30, 100]})

# %%
gcv.best_estimator_
# Out:
# RandomForestClassifier(random_state=30)

# %%
pred=gcv.best_estimator_.predict(X_test)

# %%
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 1.0
# [[1304    0]
#  [   0 1134]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
