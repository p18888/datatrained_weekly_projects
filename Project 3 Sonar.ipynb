# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
sn = pd.read_csv("/home/pavankumar/data_sci_dec/datasets/sonar_csv.csv")
sn.head()
# Out:
#    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0       0.0200       0.0371       0.0428       0.0207       0.0954
# 1       0.0453       0.0523       0.0843       0.0689       0.1183
# 2       0.0262       0.0582       0.1099       0.1083       0.0974
# 3       0.0100       0.0171       0.0623       0.0205       0.0205
# 4       0.0762       0.0666       0.0481       0.0394       0.0590
#
#    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0       0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1       0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2       0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3       0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4       0.0649       0.1209       0.2467       0.3564        0.4459  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %%
sn['Class'].value_counts()
# Out:
# Mine    111
# Rock     97
# Name: Class, dtype: int64

# %%
sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   attribute_1   208 non-null    float64
#  1   attribute_2   208 non-null    float64
#  2   attribute_3   208 non-null    float64
#  3   attribute_4   208 non-null    float64
#  4   attribute_5   208 non-null    float64
#  5   attribute_6   208 non-null    float64
#  6   attribute_7   208 non-null    float64
#  7   attribute_8   208 non-null    float64
#  8   attribute_9   208 non-null    float64
#  9   attribute_10  208 non-null    float64
#  10  attribute_11  208 non-null    float64
#  11  attribute_12  208 non-null    float64
#  12  attribute_13  208 non-null    float64
#  13  attribute_14  208 non-null    float64
#  14  attribute_15  208 non-null    float64
#  15  attribute_16  208 non-null    float64
#  16  attribute_17  208 non-null    float64
# ...

# %%
sn.describe()
# Out:
#        attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# count   208.000000   208.000000   208.000000   208.000000   208.000000
# mean      0.029164     0.038437     0.043832     0.053892     0.075202
# std       0.022991     0.032960     0.038428     0.046528     0.055552
# min       0.001500     0.000600     0.001500     0.005800     0.006700
# 25%       0.013350     0.016450     0.018950     0.024375     0.038050
# 50%       0.022800     0.030800     0.034300     0.044050     0.062500
# 75%       0.035550     0.047950     0.057950     0.064500     0.100275
# max       0.137100     0.233900     0.305900     0.426400     0.401000
#
#        attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# count   208.000000   208.000000   208.000000   208.000000    208.000000  ...
# mean      0.104570     0.121747     0.134799     0.178003      0.208259  ...
# std       0.059105     0.061788     0.085152     0.118387      0.134416  ...
# ...

# %%
sn.isnull().sum()
# Out:
# attribute_1     0
# attribute_2     0
# attribute_3     0
# attribute_4     0
# attribute_5     0
#                ..
# attribute_57    0
# attribute_58    0
# attribute_59    0
# attribute_60    0
# Class           0
# Length: 61, dtype: int64

# %%
sns.heatmap(sn.isnull())

# %%
sn.corr()
# Out:
#               attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# attribute_1      1.000000     0.735896     0.571537     0.491438     0.344797
# attribute_2      0.735896     1.000000     0.779916     0.606684     0.419669
# attribute_3      0.571537     0.779916     1.000000     0.781786     0.546141
# attribute_4      0.491438     0.606684     0.781786     1.000000     0.726943
# attribute_5      0.344797     0.419669     0.546141     0.726943     1.000000
# attribute_6      0.238921     0.332329     0.346275     0.352805     0.597053
# attribute_7      0.260815     0.279040     0.190434     0.246440     0.335422
# attribute_8      0.355523     0.334615     0.237884     0.246742     0.204006
# attribute_9      0.353420     0.316733     0.252691     0.247078     0.177906
# attribute_10     0.318276     0.270782     0.219637     0.237769     0.183219
# attribute_11     0.344058     0.297065     0.274610     0.271881     0.231684
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(sn.corr(),linecolor="black",annot=True,fmt='.2f')

# %%
sn.boxplot(figsize=(20,20))

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
le=LabelEncoder()
oe=OneHotEncoder()

# %%
sn['Class']=le.fit_transform(sn['Class'].values.reshape(-1,1))

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
n_pca=pca.fit_transform(sn.drop('Class',axis=1))
plt.figure(figsize=(50,50))
pcdf=pd.DataFrame(n_pca)
pcdf['Class']=sn['Class']
sns.heatmap(pcdf.corr(),linecolor="black",linewidths=0.5,annot=True,fmt='.2f',annot_kws={"size":20})

# %%
pcdf.boxplot(figsize=(20,20))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
X_train, X_test, y_train, y_test = train_test_split(sn.drop('Class',axis=1), 
                                                    sn['Class'], test_size=0.30, 
                                                    random_state=150)
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
logmodel.score(X_train,y_train)
# Out:
# 0.8482758620689655

# %%
predictions = logmodel.predict(X_test)

# %%
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.7301587301587301
# [[24  4]
#  [13 22]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.86      0.74        28
#            1       0.85      0.63      0.72        35
#
#     accuracy                           0.73        63
#    macro avg       0.75      0.74      0.73        63
# weighted avg       0.76      0.73      0.73        63

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(sn.drop('Class',axis=1), 
                                                    sn['Class'], test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8888888888888888 and best random state is 152

# %%
X_train, X_test, y_train, y_test = train_test_split(sn.drop('Class',axis=1), 
                                                    sn['Class'], test_size=0.30, 
                                                    random_state=152)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.8888888888888888
# [[34  2]
#  [ 5 22]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91        36
#            1       0.92      0.81      0.86        27
#
#     accuracy                           0.89        63
#    macro avg       0.89      0.88      0.88        63
# weighted avg       0.89      0.89      0.89        63

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
mod=GaussianNB()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.6825396825396826
# [[24 12]
#  [ 8 19]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71        36
#            1       0.61      0.70      0.66        27
#
#     accuracy                           0.68        63
#    macro avg       0.68      0.69      0.68        63
# weighted avg       0.69      0.68      0.68        63

# %%
def svc(a):
    mod=SVC(kernel=a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
svc("poly")
# Out:
# 0.8412698412698413
# [[32  4]
#  [ 6 21]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86        36
#            1       0.84      0.78      0.81        27
#
#     accuracy                           0.84        63
#    macro avg       0.84      0.83      0.84        63
# weighted avg       0.84      0.84      0.84        63

# %%
svc("rbf")
# Out:
# 0.8888888888888888
# [[35  1]
#  [ 6 21]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91        36
#            1       0.95      0.78      0.86        27
#
#     accuracy                           0.89        63
#    macro avg       0.90      0.88      0.88        63
# weighted avg       0.90      0.89      0.89        63

# %%
svc("linear")
# Out:
# 0.8412698412698413
# [[34  2]
#  [ 8 19]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        36
#            1       0.90      0.70      0.79        27
#
#     accuracy                           0.84        63
#    macro avg       0.86      0.82      0.83        63
# weighted avg       0.85      0.84      0.84        63

# %%
def tree(a):    
    mod=DecisionTreeClassifier(a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
tree('gini')
# Out:
# 0.6507936507936508
# [[23 13]
#  [ 9 18]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.64      0.68        36
#            1       0.58      0.67      0.62        27
#
#     accuracy                           0.65        63
#    macro avg       0.65      0.65      0.65        63
# weighted avg       0.66      0.65      0.65        63

# %%
tree('entropy')
# Out:
# 0.7619047619047619
# [[26 10]
#  [ 5 22]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78        36
#            1       0.69      0.81      0.75        27
#
#     accuracy                           0.76        63
#    macro avg       0.76      0.77      0.76        63
# weighted avg       0.77      0.76      0.76        63

# %%
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestClassifier(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        predictions = mod.predict(X_test)
        accuaracy=accuracy_score(y_test,predictions)
        if accuracy>accu:
            accu=accuracy
            best_n=i
    mod=RandomForestClassifier(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))
    print("best n is ", best_n)
    print()

# %%
rndtree(list(np.arange(100,200)),85)
# Out:
# 0.7777777777777778
# [[32  4]
#  [10 17]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82        36
#            1       0.81      0.63      0.71        27
#
#     accuracy                           0.78        63
#    macro avg       0.79      0.76      0.76        63
# weighted avg       0.78      0.78      0.77        63
#
# best n is  136

# %%
mod=KNeighborsClassifier()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.7142857142857143
# [[28  8]
#  [10 17]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76        36
#            1       0.68      0.63      0.65        27
#
#     accuracy                           0.71        63
#    macro avg       0.71      0.70      0.71        63
# weighted avg       0.71      0.71      0.71        63

# %%
#From here PCA Applied

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=40)
n_pca=pca.fit_transform(sn.drop('Class',axis=1))
plt.figure(figsize=(50,50))
pcdf=pd.DataFrame(n_pca)
pcdf['Class']=sn['Class']
sns.heatmap(pcdf.corr(),linecolor="black",linewidths=0.5,annot=True,fmt='.2f',annot_kws={"size":20})

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(pcdf.drop('Class',axis=1), 
                                                    pcdf['Class'], test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8888888888888888 and best random state is 152

# %%
# after doing PCA
X_train, X_test, y_train, y_test = train_test_split(pcdf.drop('Class',axis=1), 
                                                    pcdf['Class'], test_size=0.30, 
                                                    random_state=152)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.8888888888888888
# [[34  2]
#  [ 5 22]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91        36
#            1       0.92      0.81      0.86        27
#
#     accuracy                           0.89        63
#    macro avg       0.89      0.88      0.88        63
# weighted avg       0.89      0.89      0.89        63

# %%
# removing ouliers on PCs df

# %%
from scipy.stats import zscore
z=np.abs(zscore(pcdf.drop('Class',axis=1)))
threshold=3
len(np.where(z>3)[0]) #27
outpcdf=sn[(np.abs(zscore(pcdf.drop('Class',axis=1))) < 3).all(axis=1)]
outpcdf
# Out:
#      attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0         0.0200       0.0371       0.0428       0.0207       0.0954
# 4         0.0762       0.0666       0.0481       0.0394       0.0590
# 9         0.0164       0.0173       0.0347       0.0070       0.0187
# 10        0.0039       0.0063       0.0152       0.0336       0.0310
# 11        0.0123       0.0309       0.0169       0.0313       0.0358
# ..           ...          ...          ...          ...          ...
# 203       0.0187       0.0346       0.0168       0.0177       0.0393
# 204       0.0323       0.0101       0.0298       0.0564       0.0760
# 205       0.0522       0.0437       0.0180       0.0292       0.0351
# 206       0.0303       0.0353       0.0490       0.0608       0.0167
# 207       0.0260       0.0363       0.0136       0.0272       0.0214
#
#      attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# ...

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(outpcdf.drop('Class',axis=1), 
                                                    outpcdf['Class'], test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.9411764705882353 and best random state is 85

# %%
# after removing outliers on PCADF
X_train, X_test, y_train, y_test = train_test_split(outpcdf.drop('Class',axis=1), 
                                                    outpcdf['Class'], test_size=0.30, 
                                                    random_state=85)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9411764705882353
# [[29  0]
#  [ 3 19]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.86      0.93        22
#
#     accuracy                           0.94        51
#    macro avg       0.95      0.93      0.94        51
# weighted avg       0.95      0.94      0.94        51

# %%
pcdf.shape
# Out:
# (208, 41)

# %%
outpcdf.shape
# Out:
# (167, 61)

# %%
208-167
# Out:
# 41

# %%
(41/208)*100 ### perctage of loosing data
# Out:
# 19.71153846153846

# %%
mod=GaussianNB()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.7254901960784313
# [[21  8]
#  [ 6 16]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75        29
#            1       0.67      0.73      0.70        22
#
#     accuracy                           0.73        51
#    macro avg       0.72      0.73      0.72        51
# weighted avg       0.73      0.73      0.73        51

# %%
def svc(a):
    mod=SVC(kernel=a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
svc("poly")
# Out:
# 0.9411764705882353
# [[28  1]
#  [ 2 20]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        29
#            1       0.95      0.91      0.93        22
#
#     accuracy                           0.94        51
#    macro avg       0.94      0.94      0.94        51
# weighted avg       0.94      0.94      0.94        51

# %%
svc("rbf")
# Out:
# 0.8823529411764706
# [[29  0]
#  [ 6 16]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        29
#            1       1.00      0.73      0.84        22
#
#     accuracy                           0.88        51
#    macro avg       0.91      0.86      0.87        51
# weighted avg       0.90      0.88      0.88        51

# %%
svc("linear")
# Out:
# 0.9215686274509803
# [[29  0]
#  [ 4 18]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        29
#            1       1.00      0.82      0.90        22
#
#     accuracy                           0.92        51
#    macro avg       0.94      0.91      0.92        51
# weighted avg       0.93      0.92      0.92        51

# %%
def tree(a):    
    mod=DecisionTreeClassifier(a)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))

# %%
tree('gini')
# Out:
# 0.7647058823529411
# [[26  3]
#  [ 9 13]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81        29
#            1       0.81      0.59      0.68        22
#
#     accuracy                           0.76        51
#    macro avg       0.78      0.74      0.75        51
# weighted avg       0.77      0.76      0.76        51

# %%
tree('entropy')
# Out:
# 0.8235294117647058
# [[26  3]
#  [ 6 16]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        29
#            1       0.84      0.73      0.78        22
#
#     accuracy                           0.82        51
#    macro avg       0.83      0.81      0.82        51
# weighted avg       0.83      0.82      0.82        51

# %%
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestClassifier(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        predictions = mod.predict(X_test)
        accuracy=accuracy_score(y_test,predictions)
        if accuracy>accu:
            accu=accuracy
            best_n=i
    mod=RandomForestClassifier(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    print(accuracy_score(y_test,predictions))
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))
    print("best n is ", best_n)
    print()

# %%
rndtree(list(np.arange(100,200)),85)
# Out:
# 0.9215686274509803
# [[29  0]
#  [ 4 18]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        29
#            1       1.00      0.82      0.90        22
#
#     accuracy                           0.92        51
#    macro avg       0.94      0.91      0.92        51
# weighted avg       0.93      0.92      0.92        51
#
# best n is  111

# %%
mod=KNeighborsClassifier()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9411764705882353
# [[29  0]
#  [ 3 19]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.86      0.93        22
#
#     accuracy                           0.94        51
#    macro avg       0.95      0.93      0.94        51
# weighted avg       0.95      0.94      0.94        51

# %%
mod=LogisticRegression()
mod.fit(X_train,y_train)
predictions = mod.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
print(accuracy_score(y_test,predictions))
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# 0.9411764705882353
# [[29  0]
#  [ 3 19]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.86      0.93        22
#
#     accuracy                           0.94        51
#    macro avg       0.95      0.93      0.94        51
# weighted avg       0.95      0.94      0.94        51

# %%
# according to above analysis logistic regression and svc('rbf') is best with 89%. Before removing outliers before removing outliers

# %%
# according to above analysis logistic regression, KNN and svc('poly') is best with 94%. After removing outliers before removing outliers
