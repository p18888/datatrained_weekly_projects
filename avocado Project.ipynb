# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("/home/pavankumar/data_sci_dec/datasets/avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1            1.0  20-12-2015          1.35      54876.98    674.28   44638.81
# 2            2.0  13-12-2015          0.93     118220.22    794.70  109149.67
# 3            3.0  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4            4.0  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
df.loc[1182,'region']
# Out:
# 'TotalUS'

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.select_dtypes(include='object')
# Out:
#             Date          type     region
# 0     27-12-2015  conventional     Albany
# 1     20-12-2015  conventional     Albany
# 2     13-12-2015  conventional     Albany
# 3     06-12-2015  conventional     Albany
# 4     29-11-2015  conventional     Albany
# ...          ...           ...        ...
# 1512  16-10-2016  conventional  Charlotte
# 1513  09-10-2016  conventional  Charlotte
# 1514  02-10-2016  conventional  Charlotte
# 1515  25-09-2016  conventional  Charlotte
# 1516  18-09-2016  conventional  Charlotte
#
# [1517 rows x 3 columns]

# %%
df['region'].value_counts()
# Out:
# California             76
# Albany                 67
# Boise                  65
# BaltimoreWashington    65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Louisville             34
# Tampa                  34
# Charlotte              31
# Portland               30
# NorthernNewEngland     29
# Houston                29
# WestTexNewMexico       27
# TotalUS                25
# Nashville              25
# SouthCarolina          24
# Denver                 24
# Chicago                23
# GrandRapids            23
# Pittsburgh             22
# RichmondNorfolk        21
# Orlando                21
# Syracuse               19
# HarrisburgScranton     19
# GreatLakes             18
# ...

# %%
df['type'].is_unique  ### type column has no any unique values all the rows are similar
# Out:
# False

# %%
df.head(5)['Date']
# Out:
# 0    27-12-2015
# 1    20-12-2015
# 2    13-12-2015
# 3    06-12-2015
# 4    29-11-2015
# Name: Date, dtype: object

# %%
df.tail(5)['Date']
# Out:
# 1512    16-10-2016
# 1513    09-10-2016
# 1514    02-10-2016
# 1515    25-09-2016
# 1516    18-09-2016
# Name: Date, dtype: object

# %%
df.select_dtypes('object')
# Out:
#             Date          type     region
# 0     27-12-2015  conventional     Albany
# 1     20-12-2015  conventional     Albany
# 2     13-12-2015  conventional     Albany
# 3     06-12-2015  conventional     Albany
# 4     29-11-2015  conventional     Albany
# ...          ...           ...        ...
# 1512  16-10-2016  conventional  Charlotte
# 1513  09-10-2016  conventional  Charlotte
# 1514  02-10-2016  conventional  Charlotte
# 1515  25-09-2016  conventional  Charlotte
# 1516  18-09-2016  conventional  Charlotte
#
# [1517 rows x 3 columns]

# %%
# droping unwanted columns

# %%
df.drop(['type','Unnamed: 0'],inplace=True,axis=1)

# %%
df
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
# Lable encoding on "region" column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['encode_region']=le.fit_transform(df['region'])

# %%
# Handeling the Date column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1517 non-null   object
#  1   AveragePrice   1517 non-null   float64
#  2   Total Volume   1517 non-null   float64
#  3   4046           1517 non-null   float64
#  4   4225           1517 non-null   float64
#  5   4770           1517 non-null   float64
#  6   Total Bags     1517 non-null   float64
#  7   Small Bags     1517 non-null   float64
#  8   Large Bags     1517 non-null   float64
#  9   XLarge Bags    1517 non-null   float64
#  10  year           1517 non-null   float64
#  11  region         1517 non-null   object
#  12  encode_region  1517 non-null   int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 205.9+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Day']=df['Date'].dt.day

# %%
df['Month']=df['Date'].dt.month

# %%
df.corr()
# Out:
#                AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice       1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume      -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046              -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225              -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770              -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags        -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags        -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags        -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags       -0.048284      0.521717  0.474063  0.504718  0.646053
# year               0.178683     -0.004189 -0.040439 -0.007254  0.029222
# encode_region     -0.229408      0.236579  0.269481  0.215733  0.138092
# Day                0.092589     -0.034857 -0.031806 -0.044008 -0.021318
# ...

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  region  encode_region  Day  \
# 0     8603.62       93.25          0.0  2015.0  Albany              0   27
# 1     9408.07       97.49          0.0  2015.0  Albany              0   20
# 2     8042.21      103.14          0.0  2015.0  Albany              0   13
# 3     5677.40      133.76          0.0  2015.0  Albany              0   12
# 4     5986.26      197.69          0.0  2015.0  Albany              0   29
#
#    Month
# 0     12
# 1     12
# 2     12
# 3      6
# 4     11

# %%
df.boxplot(figsize=(15,8))

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='encode_region',y='Total Volume',data=df)

# %%
df[df['encode_region']==48]['region']
# Out:
# 1182    TotalUS
# 1183    TotalUS
# 1184    TotalUS
# 1185    TotalUS
# 1186    TotalUS
# 1187    TotalUS
# 1188    TotalUS
# 1189    TotalUS
# 1190    TotalUS
# 1191    TotalUS
# 1192    TotalUS
# 1193    TotalUS
# 1194    TotalUS
# 1195    TotalUS
# 1196    TotalUS
# 1197    TotalUS
# 1198    TotalUS
# 1199    TotalUS
# 1200    TotalUS
# 1201    TotalUS
# 1202    TotalUS
# 1203    TotalUS
# 1204    TotalUS
# 1205    TotalUS
# 1206    TotalUS
# Name: region, dtype: object

# %%
df[df['encode_region']==6]['region']
# Out:
# 184     California
# 185     California
# 186     California
# 187     California
# 188     California
#            ...
# 1497    California
# 1498    California
# 1499    California
# 1500    California
# 1501    California
# Name: region, Length: 76, dtype: object

# %%
df[df['region']=='TotalUS']
# Out:
#       AveragePrice  Total Volume         4046         4225        4770  \
# 1182          1.02   35734613.90  14699604.93  13244466.60  1326422.56
# 1183          0.98   37026085.75  16383685.07  12821015.03  1085081.61
# 1184          1.00   36549995.66  16529797.60  12582265.21  1144715.95
# 1185          1.03   33720159.09  15503613.33  11599634.02   903908.35
# 1186          1.04   35344183.15  16000107.80  12513821.19   899779.92
# 1187          1.06   32027686.15  14615941.59  11003341.22   963549.53
# 1188          1.02   36400886.58  16215328.75  13509064.65   858145.45
# 1189          0.96   41291704.39  17787611.93  16602589.04  1118329.50
# 1190          1.07   30894157.80  13833715.28  10867403.08   889732.20
# 1191          1.03   33091256.26  14251319.31  12277858.78  1016631.26
# 1192          1.02   32046401.64  14793354.18  11210544.11   807942.41
# 1193          1.06   31500669.44  13939014.43  11526980.36   871981.29
# ...

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='encode_region',y='4046',data=df)

# %%
# Observing all above boxplot it shows that outliers having only because in "TotalUS" and "California" having 
#high total values.. Looks like outliers are legitimate

# %%
df.skew()
# Out:
# AveragePrice    -0.109444
# Total Volume     6.200138
# 4046             6.051830
# 4225             6.394926
# 4770             5.405164
# Total Bags       5.366378
# Small Bags       5.355185
# Large Bags       5.144495
# XLarge Bags      5.775077
# year             1.828332
# encode_region    0.288146
# Day              0.041303
# Month            0.101439
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
for i in ['4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']:    
    sns.distplot(df[i])
    plt.show()
    print(f'Column Name is : {i} \n==================Before removing Skewness is {df[i].skew()}\n')
    df[i] =pt.fit_transform(pd.DataFrame(df[i]),0.5)
    sns.distplot(df[i])
    plt.show()
    print(f'Column Name is : {i} \n==================After removing Skewness is {df[i].skew()}\n')
# Out:
# Column Name is : 4046
# ==================Before removing Skewness is 6.051830422930919
# Column Name is : 4046
# ==================After removing Skewness is -0.01205877866645369
# Column Name is : 4225
# ==================Before removing Skewness is 6.394926370116106
# Column Name is : 4225
# ==================After removing Skewness is 0.008449869006237443
# Column Name is : 4770
# ==================Before removing Skewness is 5.405164157563797
# Column Name is : 4770
# ==================After removing Skewness is -0.032945375860409604
# Column Name is : Total Bags
# ==================Before removing Skewness is 5.366378496698982
# Column Name is : Total Bags
# ==================After removing Skewness is 0.005204651006386219
# Column Name is : Small Bags
# ==================Before removing Skewness is 5.3551847488193465
# Column Name is : Small Bags
# ==================After removing Skewness is 0.02763159123050707
# Column Name is : Large Bags
# ...

# %%
sns.distplot(df['Total Volume'])

# %%
df['Total Volume']=np.log(df['Total Volume'])

# %%
df['Total Volume'].skew()
# Out:
# 0.6674608508123422

# %%
plt.figure(figsize=(20,8))
df.boxplot()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidths=0.5,fmt='.3f')

# %%
# Heat map show that [Month, small bags, XL bags] columns is not much correlating with Averae Price

# %%
# Rather than loosing the data applying PCA

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'year', 'region',
#        'encode_region', 'Day', 'Month'],
#       dtype='object')

# %%
df.drop('region',axis=1,inplace=True)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error,accuracy_score,r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(df.drop(['AveragePrice'],axis=1),df['AveragePrice'], test_size=0.25,random_state=i)
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    pred = lr.predict(X_test)
    rscrore=r2_score(y_test,pred)
    crv=cross_val_score(LinearRegression(),X_train,y_train,cv=10).mean()
    if rscrore>accu:
        accu=rscrore
        best_state=i
print(f"Final accuracy is {accu*100} \n Cross Validate score is {(crv*100)} \n# difference is {(accu*100)-(crv*100)} \n best random state is{best_state}")
# Out:
# Final accuracy is 44.14511849175585
#  Cross Validate score is 34.78360414242503
# # difference is 9.361514349330825
#  best random state is139

# %% [markdown]
# # Pipeline

# %%
from sklearn.pipeline import Pipeline

# %%
 X_train, X_test, y_train, y_test = train_test_split(df.drop(['AveragePrice'],axis=1),df['AveragePrice'], test_size=0.25, 
                                                    random_state=139)

# %%
parameters_sgd={
 'penalty': ['l1','l2','elasticnet'],
 'alpha': [0.0001,0.001,0.01,0.1,1],
    'max_iter':[1000,2000],
}
parameters_rndf={
 'criterion': ['mse','mae'],
 'max_features': ['auto','sqrt'],
 'n_estimators': list(np.arange(100,150)),
 'random_state': [202],
    'max_depth':[5],
}
parameters_deci_tree={
 'criterion': ['mse','mae'],
#  'splitter':['best','random'],
 'max_features': ['auto','sqrt'],
 'max_depth':[5],
 'random_state': [202]}
parameters_knn_reg={
    'n_neighbors': list(np.arange(5,10)),
    'weights':['uniform','distance'],
    
}
parameters_svr_reg={
    'kernel': ['linear','poly','rbf'],
#     'gamma':['auto','scale'],
#     'max_iter':[500,700,900,1100,1300,1500,1700],
    'max_iter':[500,700],
    
}
parameters_linear_reg = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}

# %%
parameter_lis=[parameters_linear_reg,parameters_knn_reg,parameters_svr_reg,parameters_deci_tree,parameters_sgd]
models=[LinearRegression(),KNeighborsRegressor(),SVR(),DecisionTreeRegressor(),SGDRegressor()]
models_name=['LinearRegression','KNeighborsRegressor','SVR','DecisionTreeRegressor','SGDRegressor']
lis_pipes=[]    
best_score=0
best_model_name=''
cv_score=0
for n,model,model_name,parameter in zip(np.arange(1,6),models,models_name,parameter_lis):
    lis_pipes.append(Pipeline([(model_name,GridSearchCV(estimator=model,param_grid=parameter,cv=5,scoring='r2'))]))

for model in lis_pipes:
    gsv=model.fit(X_train,y_train)
    pred=gsv[0].best_estimator_.predict(X_test)
    r2score=r2_score(y_test,pred)
    crv=cross_val_score(model,X_train,y_train,cv=2).mean()
    print(f"Final accuracy is {r2score*100} \n\nCross Validate score is {(crv*100)}\n\n{gsv[0].best_estimator_}\n\n{gsv[0].best_params_}\n\n=====================================================")
    if r2score>best_score and crv>0:
        best_score=r2score
        best_model_name=[]
        best_model_name.append(gsv[0])
        
print(f"Best model name is :  {best_model_name[0]}")
# Out:
# Final accuracy is 44.017803124219135
#
# Cross Validate score is 30.645391220420017
#
# LinearRegression(fit_intercept=False, normalize=True)
#
# {'copy_X': True, 'fit_intercept': False, 'normalize': True}
#
# ...
# Final accuracy is 52.84432287775385
#
# Cross Validate score is 28.62300429621299
#
# KNeighborsRegressor(weights='distance')
#
# {'n_neighbors': 5, 'weights': 'distance'}
#
# ...
# Final accuracy is 5.126089337467265
#
# Cross Validate score is 1.9176925333044104
#
# SVR(kernel='poly', max_iter=500)
#
# {'kernel': 'poly', 'max_iter': 500}
#
# ...
# Final accuracy is 59.75620063249488
#
# Cross Validate score is 45.97462636459098
#
# DecisionTreeRegressor(criterion='mae', max_depth=5, max_features='auto',
#                       random_state=202)
#
# {'criterion': 'mae', 'max_depth': 5, 'max_features': 'auto', 'random_state': 202}
#
# ...
# Final accuracy is -7.998300312992766e+32
#
# Cross Validate score is -1.9523605173933124e+33
#
# SGDRegressor(alpha=0.001, max_iter=2000, penalty='l1')
#
# ...

# %%
######  criterion{“mse”, “mae”}, default=”mse”
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestRegressor(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        pred = mod.predict(X_test)
        accuracy=r2_score(y_test,pred)
        if accuracy>accu:
            accu=accuracy
            best_n=i
    mod=RandomForestRegressor(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    print(r2_score(y_test,predictions)*100)
    print((cross_val_score(RandomForestRegressor(),X_train,y_train,cv=5).mean()*100))
    print("best n is ", best_n)

# %%
rndtree(list(np.arange(120,170)),139)
# Out:
# 82.05891956112292
# 77.26028040523639
# best n is  167

# %%
def rftree(a,b,c):
    mod=RandomForestRegressor(n_estimators=i,random_state=b,criterion=c)
    mod.fit(X_train,y_train)
    pred = mod.predict(X_test)
    print(r2_score(y_test,pred)*100)
    print((cross_val_score(RandomForestRegressor(n_estimators=i,random_state=b,criterion=c),X_train,y_train,cv=5).mean()*100))

# %%
rftree(167,139,'mae')
# Out:
# 81.74443908728084
# 78.1161247410995

# %%
rftree(167,139,'mse')
# Out:
# 82.02761912813796
# 77.6468556761371

# %%
rfc=RandomForestRegressor(n_estimators=167,random_state=139,criterion='mae')
rfc.fit(X_train,y_train)
# Out:
# RandomForestRegressor(criterion='mae', n_estimators=167, random_state=139)

# %% [markdown]
# # Conclusion: Best Model is RandomForestRegressor from all above models

# %%
import pickle
file_name='avocado_model.pkl'
pickle.dump(rfc,open(file_name,'wb'))

# %%
df
# Out:
#       AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0             1.33     11.070329 -1.757736 -0.545363 -1.675878   -2.030217
# 1             1.35     10.912849 -1.919557 -0.667814 -1.619934   -1.931468
# 2             0.93     11.680304 -1.857996 -0.124940 -1.375858   -2.103934
# 3             1.08     11.277104 -1.724410 -0.375219 -1.555093   -2.497084
# 4             1.28     10.840357 -1.794175 -0.679011 -1.542167   -2.422996
# ...            ...           ...       ...       ...       ...         ...
# 1512          1.39     12.159222 -0.143482 -0.524209  0.417378   -0.194163
# 1513          1.51     12.090862 -0.263771 -0.571452  0.460902   -0.143253
# 1514          1.48     12.091844 -0.235102 -0.563222  0.397721   -0.154530
# 1515          1.47     12.150198 -0.169554 -0.555147  0.416497   -0.135323
# 1516          1.43     12.117123 -0.265818 -0.548316  0.393326   -0.073585
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# for best random state
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(df.drop(['encode_region'],axis=1),df['encode_region'], test_size=0.25,random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.35526315789473684 and best random state is 173

# %% [markdown]
# ## Pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['encode_region'],axis=1),df['encode_region'], 
                                                    test_size=0.30, 
                                                    random_state=173)

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
accuracy_score(y_test,predictions)
# Out:
# 0.26973684210526316

# %%
parameters_deci_c={
 'criterion': ['gini','entropy'],
 'splitter':['best','random'],
 'max_features': ['auto','sqrt'],
 'max_depth':[5],
 'random_state': [173]}

parameters_knn_c={
    'n_neighbors': list(np.arange(5,10)),
    'weights':['uniform','distance'],
#     'algorithm':['auto','ball_tree','kd_tree','brute']
    
}
parameters_svc={
    'kernel': ['linear','poly','rbf','sigmoid'],
    'gamma':['auto','scale'],
#     'max_iter':[500,700,900,1100,1300,1500,1700],
    'max_iter':[500,700],
    
}
parameters_log_reg = {'penalty':['l1', 'l2', 'elasticnet'],
                      'solver':['newton-cg','lbfgs','liblinear','sag','saga']
                     }

# %%
parameter_lis=[parameters_log_reg,parameters_knn_c,parameters_svc,parameters_deci_c]
models=[LogisticRegression(),KNeighborsClassifier(),SVC(),DecisionTreeClassifier()]
models_name=['LogisticRegression','KNeighborsClassifier','SVC','DecisionTreeClassifier']
lis_pipes=[]    
best_score=0
best_model_name=''
cv_score=0
for n,model,model_name,parameter in zip(np.arange(1,6),models,models_name,parameter_lis):
    lis_pipes.append(Pipeline([(model_name,GridSearchCV(estimator=model,param_grid=parameter,cv=5,scoring='accuracy'))]))

for model in lis_pipes:
    gsv=model.fit(X_train,y_train)
    pred=gsv[0].best_estimator_.predict(X_test)
    crv=cross_val_score(model,X_train,y_train,cv=2).mean()
    accuracy=accuracy_score(y_test,pred)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred)*100,'%')
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print('Best Parameters are : ',gsv[0].best_params_)
    print(f'Cross Validation Score is : {crv}\nModel name is {gsv}\n==============================================================================')
    if accuracy>best_score:
        best_score=accuracy
        best_model_name=[]
        best_model_name.append(gsv[0])
        
print(f"Best model name is :  {best_model_name[0]}")
# Out:
# Accuracy  Score is :  85.08771929824562 %
# [[21  0  0 ...  0  0  0]
#  [ 0 10  0 ...  0  0  0]
#  [ 0  0 16 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  8  0]
#  [ 0  0  0 ...  0  0  5]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        22
#            1       0.62      0.71      0.67        14
#            2       0.76      0.94      0.84        17
#            3       0.95      0.95      0.95        20
#            4       0.95      0.90      0.92        20
#            5       1.00      0.92      0.96        13
#            6       0.71      1.00      0.83        15
#            7       0.64      0.90      0.75        10
#            8       1.00      0.71      0.83         7
#            9       0.95      1.00      0.98        20
#           10       0.43      0.75      0.55         4
#           11       1.00      0.89      0.94         9
#           12       1.00      1.00      1.00        16
# ...

# %%
######  'criterion': ['gini','entropy'], default=”mse”
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestClassifier(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        pred = mod.predict(X_test)
        accuracy=accuracy_score(y_test,pred)
        if accuracy>accu:
            accu=accuracy
            best_n=i
    mod=RandomForestClassifier(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print((cross_val_score(RandomForestClassifier(),X_train,y_train,cv=5).mean()*100))
    print("best n is ", best_n)

# %%
rndtree(list(np.arange(120,170)),214)
# Out:
# Accuracy  Score is :  0.956140350877193
# [[22  0  0 ...  0  0  0]
#  [ 0 14  0 ...  0  0  0]
#  [ 0  0 17 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  8  0]
#  [ 0  0  0 ...  0  0  6]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       0.82      1.00      0.90        14
#            2       0.94      1.00      0.97        17
#            3       1.00      1.00      1.00        20
#            4       1.00      0.95      0.97        20
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        15
#            7       0.91      1.00      0.95        10
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00        20
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00        16
# ...

# %%
def rftree(a,b,c):
    mod=RandomForestClassifier(n_estimators=i,random_state=b,criterion=c)
    mod.fit(X_train,y_train)
    pred = mod.predict(X_test)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print((cross_val_score(RandomForestClassifier(n_estimators=i,random_state=b,criterion=c),X_train,y_train,cv=5).mean()*100))

# %%
rftree(173,135,'gini')
# Out:
# Accuracy  Score is :  0.9627192982456141
# [[22  0  0 ...  0  0  0]
#  [ 0 14  0 ...  0  0  0]
#  [ 0  0 17 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  8  0]
#  [ 0  0  0 ...  0  0  6]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       0.88      1.00      0.93        14
#            2       0.94      1.00      0.97        17
#            3       1.00      1.00      1.00        20
#            4       1.00      0.95      0.97        20
#            5       1.00      1.00      1.00        13
#            6       1.00      1.00      1.00        15
#            7       0.91      1.00      0.95        10
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00        20
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00        16
# ...

# %%
rftree(173,135,'entropy')
# Out:
# Accuracy  Score is :  0.9429824561403509
# [[22  0  0 ...  0  0  0]
#  [ 0 14  0 ...  0  0  0]
#  [ 0  0 17 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  6  0]
#  [ 0  0  0 ...  0  0  6]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       0.82      1.00      0.90        14
#            2       0.94      1.00      0.97        17
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        13
#            6       0.79      1.00      0.88        15
#            7       0.83      1.00      0.91        10
#            8       1.00      1.00      1.00         7
#            9       1.00      1.00      1.00        20
#           10       0.80      1.00      0.89         4
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00        16
# ...

# %%
rfc=RandomForestClassifier(n_estimators=173,random_state=135,criterion='gini')
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=122, random_state=233)

# %%
import pickle
file_name='avocado_model.pkl'
pickle.dump(rfc,open(file_name,'wb'))
