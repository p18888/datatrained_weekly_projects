# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("/home/pavankumar/data_sci_dec/datasets/Censum Income Dataset/adult.data",
                names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship',
                      'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Target'])
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Target            0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# #### Heatmap shows that there is no null values present in Data set

# %%
df['Target'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: Target, dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# Target            object
# dtype: object

# %%
plt.hist(df['age'])
plt.show()

# %%
sns.boxplot(df['age'])

# %%
sns.countplot('sex',hue='race',data=df)

# %%
sns.countplot('sex',hue='Target',data=df)

# %%
plt.figure(figsize=(12,8))
sns.countplot('race',hue='Target',data=df)

# %%
plt.figure(figsize=(12,8))
sns.countplot('marital-status',hue='Target',data=df)

# %%
plt.figure(figsize=(18,8))
sns.countplot('education',hue='Target',data=df)

# %%
plt.figure(figsize=(14,8))
sns.set_style(style='darkgrid')
sns.boxplot(x='Target',y='age',data=df,hue='sex')

# %%
sns.boxplot(df['fnlwgt'])

# %%
plt.figure(figsize=(14,8))
sns.set_style(style='darkgrid')
sns.boxplot(x='Target',y='fnlwgt',data=df,hue='marital-status')

# %%
plt.figure(figsize=(14,8))
sns.set_style(style='darkgrid')
sns.boxplot(x='Target',y='fnlwgt',data=df,hue='workclass')

# %%
sns.distplot(df['fnlwgt'])

# %%
sns.distplot(df['age'])

# %%
for i in ['age','fnlwgt','capital-gain','capital-loss','hours-per-week']:
    print(i)
    sns.distplot(df[i])
    plt.show()
    sns.boxplot(df[i])
    plt.show()
    print(df[i].value_counts(),'==============================',len(df[i].value_counts()),'\nAnd Sckewness is :',df[i].skew())
# Out:
# age
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64 ============================== 73
# And Sckewness is : 0.5587433694130484
# fnlwgt
# 164190    13
# 203488    13
# 123011    13
# 113364    12
# 121124    12
#           ..
# 284211     1
# 312881     1
# 177711     1
# 179758     1
# 229376     1
# Name: fnlwgt, Length: 21648, dtype: int64 ============================== 21648
# And Sckewness is : 1.4469800945789826
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: capital-gain, Length: 119, dtype: int64 ============================== 119
# And Sckewness is : 11.953847687699799
# capital-loss
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# ...

# %%
df.boxplot(figsize=(18,8))

# %%
df['fnlwgt'].argmax()
# Out:
# 14449

# %%
df['fnlwgt'].min()
# Out:
# 12285

# %%
df.loc[14449,:]
# Out:
# age                             25
# workclass                  Private
# fnlwgt                     1484705
# education             Some-college
# education-num                   10
# marital-status            Divorced
# occupation         Exec-managerial
# relationship             Unmarried
# race                         White
# sex                         Female
# capital-gain                     0
# capital-loss                     0
# hours-per-week                  25
# native-country       United-States
# Target                       <=50K
# Name: 14449, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Target']=le.fit_transform(df['Target'])
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
# Target          0.234037 -0.009463       0.335154      0.223329      0.150526
#
#                 hours-per-week    Target
# age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education-num         0.148123  0.335154
# capital-gain          0.078409  0.223329
# capital-loss          0.054256  0.150526
# hours-per-week        1.000000  0.229689
# Target                0.229689  1.000000

# %%
df[df['workclass']==' ?']
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 27      54         ?  180211   Some-college             10
# 61      32         ?  293936        7th-8th              4
# 69      25         ?  200681   Some-college             10
# 77      67         ?  212759           10th              6
# 106     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32530   35         ?  320084      Bachelors             13
# 32531   30         ?   33811      Bachelors             13
# 32539   71         ?  287372      Doctorate             16
# 32541   41         ?  202822        HS-grad              9
# 32542   72         ?  129912        HS-grad              9
#
#                marital-status occupation    relationship                 race  \
# 27         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61      Married-spouse-absent          ?   Not-in-family                White
# ...

# %%
df.replace(' ?',np.nan,inplace=True)
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# Target               0
# dtype: int64

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
# ...

# %%
df.replace(np.nan,'Other',inplace=True)
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Target            0
# dtype: int64

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
# Other                 1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df['workclass']=='Other'].head(1)
# Out:
#     age workclass  fnlwgt      education  education-num       marital-status  \
# 27   54     Other  180211   Some-college             10   Married-civ-spouse
#
#    occupation relationship                 race    sex  capital-gain  \
# 27      Other      Husband   Asian-Pac-Islander   Male             0
#
#     capital-loss  hours-per-week native-country  Target
# 27             0              60          South       1

# %%
df[df['occupation']=='Other'].head(1)
# Out:
#     age workclass  fnlwgt      education  education-num       marital-status  \
# 27   54     Other  180211   Some-college             10   Married-civ-spouse
#
#    occupation relationship                 race    sex  capital-gain  \
# 27      Other      Husband   Asian-Pac-Islander   Male             0
#
#     capital-loss  hours-per-week native-country  Target
# 27             0              60          South       1

# %%
df[df['native-country']=='Other'].head(1)
# Out:
#     age workclass  fnlwgt   education  education-num       marital-status  \
# 14   40   Private  121772   Assoc-voc             11   Married-civ-spouse
#
#        occupation relationship                 race    sex  capital-gain  \
# 14   Craft-repair      Husband   Asian-Pac-Islander   Male             0
#
#     capital-loss  hours-per-week native-country  Target
# 14             0              40          Other       1

# %%
for i in ['workclass','education','marital-status','occupation','relationship','race','sex','native-country']:
    df[i]=le.fit_transform(df[i])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int64
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  int64
#  6   occupation      32561 non-null  int64
#  7   relationship    32561 non-null  int64
#  8   race            32561 non-null  int64
#  9   sex             32561 non-null  int64
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  int64
#  14  Target          32561 non-null  int64
# dtypes: int64(15)
# memory usage: 3.7 MB

# %%
df.loc[27,'workclass']
# Out:
# 8

# %%
df.loc[27,'occupation']
# Out:
# 14

# %%
df.loc[14,'native-country']
# Out:
# 41

# %%
# df['workclass'].replace(8,np.nan)
# df['workclass'].replace(14,np.nan)
# df['workclass'].replace(41,np.nan)

# from sklearn.impute import KNNImputer
# knni=KNNImputer()
# df1=knni.fit_transform(df)
# df1=pd.DataFrame(df1)

# for i in df1.columns:
#     print("Column name is ",i)
#     print(df1[i].value_counts(),'\n')
#     print(f'\n Total Number of Categoricals in {i} ==> {len(df1[i].value_counts())}\n')
#     print("==============================")

# %%
sns.heatmap(df.isnull())

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(),annot=True,fmt='.2%',linewidths=0.5)

# %%
# from heatmap 'fnlwgt' is less correlating with Target column

# %%
df.drop('fnlwgt',axis=1,inplace=True)

# %% [markdown]
# ### Standard Scalling

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()

# %%
target=df["Target"]
x=df.drop('Target',axis=1)

# %%
x.head(2)
# Out:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0   39          6          9             13               4           0
# 1   50          5          9             13               2           3
#
#    relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0             1     4    1          2174             0              40
# 1             0     4    1             0             0              13
#
#    native-country
# 0              38
# 1              38

# %%
ss_x=st.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# for best random state after standard scaller
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(pd.DataFrame(ss_x), 
                                                    target, test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8326338417442932 and best random state is 214

# %%
# for best random state before standard scaller
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    target, test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8196335346504248 and best random state is 152

# %%
# Before standard scaller
X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    target, test_size=0.30, 
                                                    random_state=152)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
accuracy_score(y_test,predictions)
# Out:
# 0.8196335346504248

# %%
# After Standard scaller
X_train, X_test, y_train, y_test = train_test_split(ss_x, 
                                                    target, test_size=0.30, 
                                                    random_state=214)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
accuracy_score(y_test,predictions)
# Out:
# 0.8326338417442932

# %%
# Observation :  Standard scaller giving better output

# %% [markdown]
# ### Pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(ss_x, 
                                                    target, test_size=0.30, 
                                                    random_state=214)

# %%
parameters_deci_c={
 'criterion': ['gini','entropy'],
 'splitter':['best','random'],
 'max_features': ['auto','sqrt'],
 'max_depth':[5],
 'random_state': [233]}

parameters_knn_c={
    'n_neighbors': list(np.arange(5,10)),
    'weights':['uniform','distance'],
#     'algorithm':['auto','ball_tree','kd_tree','brute']
    
}
parameters_svc={
    'kernel': ['linear','poly','rbf','sigmoid'],
    'gamma':['auto','scale'],
#     'max_iter':[500,700,900,1100,1300,1500,1700],
    'max_iter':[500,700],
    
}
parameters_log_reg = {'penalty':['l1', 'l2', 'elasticnet'],
                      'solver':['newton-cg','lbfgs','liblinear','sag','saga']
                     }

# %%
parameter_lis=[parameters_log_reg,parameters_knn_c,parameters_svc,parameters_deci_c]
models=[LogisticRegression(),KNeighborsClassifier(),SVC(),DecisionTreeClassifier()]
models_name=['LogisticRegression','KNeighborsClassifier','SVC','DecisionTreeClassifier']
lis_pipes=[]    
best_score=0
best_model_name=''
cv_score=0
for n,model,model_name,parameter in zip(np.arange(1,6),models,models_name,parameter_lis):
    lis_pipes.append(Pipeline([(model_name,GridSearchCV(estimator=model,param_grid=parameter,cv=5,scoring='accuracy'))]))

for model in lis_pipes:
    gsv=model.fit(X_train,y_train)
    pred=gsv[0].best_estimator_.predict(X_test)
    crv=cross_val_score(model,X_train,y_train,cv=2).mean()
    accuracy=accuracy_score(y_test,pred)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred)*100,'%')
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print('Best Parameters are : ',gsv[0].best_params_)
    print(f'Cross Validation Score is : {crv}\nModel name is {gsv}\n==============================================================================')
    if accuracy>best_score:
        best_score=accuracy
        best_model_name=[]
        best_model_name.append(gsv[0])
        
print(f"Best model name is :  {best_model_name[0]}")
# Out:
# Accuracy  Score is :  83.26338417442932 %
# [[7056  414]
#  [1221 1078]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90      7470
#            1       0.72      0.47      0.57      2299
#
#     accuracy                           0.83      9769
#    macro avg       0.79      0.71      0.73      9769
# weighted avg       0.82      0.83      0.82      9769
#
# Best Parameters are :  {'penalty': 'l1', 'solver': 'saga'}
# Cross Validation Score is : 0.8218673218673218
# Model name is Pipeline(steps=[('LogisticRegression',
#                  GridSearchCV(cv=5, estimator=LogisticRegression(),
#                               param_grid={'penalty': ['l1', 'l2', 'elasticnet'],
#                                           'solver': ['newton-cg', 'lbfgs',
#                                                      'liblinear', 'sag',
#                                                      'saga']},
# ...

# %%
######  'criterion': ['gini','entropy'], default=”mse”
def rndtree(a,b):
    accu=0
    best_n=0
    for i in a:
        mod=RandomForestClassifier(n_estimators=i,random_state=b)
        mod.fit(X_train,y_train)
        pred = mod.predict(X_test)
        accuracy=accuracy_score(y_test,pred)
        if accuracy>accu:
            accu=accuracy
            best_n=i
    mod=RandomForestClassifier(n_estimators=best_n,random_state=b)
    mod.fit(X_train,y_train)
    predictions = mod.predict(X_test)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print((cross_val_score(RandomForestClassifier(),X_train,y_train,cv=5).mean()*100))
    print("best n is ", best_n)

# %%
rndtree(list(np.arange(120,170)),214)
# Out:
# Accuracy  Score is :  0.8508547446002661
# [[6852  618]
#  [ 839 1460]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      7470
#            1       0.70      0.64      0.67      2299
#
#     accuracy                           0.85      9769
#    macro avg       0.80      0.78      0.79      9769
# weighted avg       0.85      0.85      0.85      9769
#
# 84.66562771506071
# best n is  122

# %%
def rftree(a,b,c):
    mod=RandomForestClassifier(n_estimators=i,random_state=b,criterion=c)
    mod.fit(X_train,y_train)
    pred = mod.predict(X_test)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print((cross_val_score(RandomForestClassifier(n_estimators=i,random_state=b,criterion=c),X_train,y_train,cv=5).mean()*100))

# %%
rftree(122,214,'gini')
# Out:
# Accuracy  Score is :  0.8515712969597707
# [[6863  607]
#  [ 843 1456]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      7470
#            1       0.71      0.63      0.67      2299
#
#     accuracy                           0.85      9769
#    macro avg       0.80      0.78      0.79      9769
# weighted avg       0.85      0.85      0.85      9769
#
# 84.74897932725638

# %%
rftree(122,214,'entropy')
# Out:
# Accuracy  Score is :  0.8513665677141979
# [[6873  597]
#  [ 855 1444]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      7470
#            1       0.71      0.63      0.67      2299
#
#     accuracy                           0.85      9769
#    macro avg       0.80      0.77      0.78      9769
# weighted avg       0.85      0.85      0.85      9769
#
# 84.77529318926221

# %%
rfc = RandomForestClassifier(n_estimators=122,random_state=214,criterion='gini')
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=122, random_state=214)

# %% [markdown]
# # Conclusion  Best model is Random Forest Classifier

# %%
import pickle
file_name='census_model.pkl'
pickle.dump(rfc,open(file_name,'wb'))
